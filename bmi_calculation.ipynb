# %%
import numpy as np
import pandas as pd
#from numpy import loadtxt 

#data=pd.read_csv('~/Desktop/python/dataBaseball2.csv',sep=';')
#data=pd.read_excel('/Desktop/python/dataBaseball.xls')
#pd.read_csv('file.csv', header=None, nrows=5)

# %%
file1=np.loadtxt("dataBaseball.csv",delimiter =',',dtype=str)
file2=np.genfromtxt("dataBaseball.csv",delimiter=';',dtype=np.int32,skip_header=1)
#np.genfromtxt('/Users/mdsanowarhossain/Desktop/dataBaseball.csv',delimiter=';')

# %%
file2
# Out:
# array([[    -1,     -1,     -1, ...,     -1,     -1,     -1],
#        [  1001,     -1,     69, ...,     74,     35,     66],
#        [100143,     -1,     65, ...,     -1,     -1,     -1],
#        ...,
#        [  9807,     -1,     68, ...,     -1,     -1,     -1],
#        [  9815,     -1,     65, ...,     -1,     -1,     -1],
#        [  9913,     -1,     69, ...,     -1,     -1,     -1]], dtype=int32)

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-568259ba2142> in <module>
# ----> 1 df=data.index(id)
#
# TypeError: 'RangeIndex' object is not callable

# %%
display(data)
# Out:
#           id                     name   rating  position   height    foot  \
# 0       1001           GÃ¡bor KirÃ¡ly       69        GK      191   Right
# 1     100143             Frederik Boi       65         M      184   Right
# 2     100264          Tomasz Szewczuk       57         A      185   Right
# 3     100325   Steeve Joseph-Reinette       63         D      180    Left
# 4     100326             Kamel Chafni       72         M      181   Right
# ...      ...                      ...      ...       ...      ...     ...
# 8842    9801          Danijel Ljuboja       73         A      189    Left
# 8843    9805            Craig Bellamy       79         A      175   Right
# 8844    9807            Michel Breuer       68         D      183   Right
# 8845    9815              Gill Swerts       65         D      179   Right
# 8846    9913              Mehdi Nafti       69         M      179   Right
#
#        rare  pace  shooting  passing  dribbling  defending  heading  diving  \
# ...

# %%
data[['height']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-61156046c5fa> in <module>
# ----> 1 data[['height']]
#       2 #df[['AirPollutant','Concentration','year']]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
# ...
